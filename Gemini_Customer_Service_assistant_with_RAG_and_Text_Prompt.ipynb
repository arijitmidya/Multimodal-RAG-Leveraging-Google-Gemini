# %%
! pip install PyPDF2
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 5.6 MB/s eta 0:00:00
# ...

# %%
# !pip install langchain-google-genai
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.6/50.6 kB 2.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.4/40.4 kB 2.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 407.7/407.7 kB 17.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.9/296.9 kB 18.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.0/78.0 kB 4.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.5/144.5 kB 9.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 3.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 3.9 MB/s eta 0:00:00
# ...

# %%
# !pip install langchain
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 17.8 MB/s eta 0:00:00
# ...

# %%
# !pip install langchain-community
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 31.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.5/49.5 kB 3.1 MB/s eta 0:00:00
# ...

# %%
# !pip install chromadb
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 4.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 607.0/607.0 kB 24.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 64.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 273.8/273.8 kB 19.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.6/94.6 kB 7.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 63.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.2/93.2 kB 6.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.2/13.2 MB 64.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.5/52.5 kB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.7/149.7 kB 11.6 MB/s eta 0:00:00
# ...

# %%
# Standard library imports
import os
import io
import getpass
import json

# Third-party library imports
import PyPDF2
import requests
import numpy as np
import ipywidgets as widgets
from IPython.display import display, Markdown

# Google generative AI imports
import google.generativeai as genai

# LangChain imports
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_google_genai import GoogleGenerativeAIEmbeddings
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.schema.document import Document
from langchain_community.document_loaders import TextLoader
from langchain_core.runnables import RunnableLambda, RunnablePassthrough

# Chromadb imports
import chromadb
from chromadb import Documents, EmbeddingFunction, Embeddings

# %%
GOOGLE_API_KEY ="add your gemini keys here"
genai.configure(api_key=GOOGLE_API_KEY)

# %%
# Method to process the PDF
def process_pdf(file_path):
    # PDF processing
    with open(file_path, 'rb') as file:
        pdf_reader = PyPDF2.PdfReader(file)
        pdf_pages = pdf_reader.pages

        # Create chunks for each shoe detail page
        shoe_details = []
        for page_num, page in enumerate(pdf_pages, start=1):

            page_text = page.extract_text()
            # Split the text into lines and remove any empty lines
            lines = [line.strip() for line in page_text.splitlines() if line.strip()]

            # Join lines into continuous text
            consolidated_text = ' '.join(lines)
            shoe_details.append(consolidated_text)

            # PDF reading is done

        # Generate chunks for each shoe detail
        shoe_chunks = []
        for shoe_detail in shoe_details:
              chunks = get_text_chunks_langchain(shoe_detail)
              shoe_chunks.append(chunks)

        return shoe_chunks

# %%
# Method to generate chunks
def get_text_chunks_langchain(text):
    text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=1)
    chunks = text_splitter.split_text(text)
    docs = [x for x in chunks]
    return docs

# %%
shoe_chunks = process_pdf("ShoesStore.pdf")

# %%
shoe_chunks[0]
# Out:
# ['Adidas Ultraboost 22sneakers Style:Running Releasedate:February4,2021 Stylecode:FY0377 Originalretailprice:$180USD StoreLocation:5thAvenue&Broadway,NewYork,NY10011.Phone:(212) 555-1234. Description: TheyfeatureablackupperwithablackAdidasStripeslogoontheside andaBoostmidsoleforcushioning.Thesoleisblack. TheUltraboost22isapopularAdidasrunningshoethatcombinescomfort andperformance.ItfeaturesaPrimeknitupper,aBoostmidsolefor responsivecushioning,andaContinentalrubberoutsoleforsuperior traction.']

# %%
shoe_chunks[1]
# Out:
# ['Adidas NMD_R1 sneakers Style:Casual Releasedate:December12,2015 Stylecode:S79168 Originalretailprice:$130USD StoreLocation:3rdStreetPromenade,SantaMonica,CA90401.Phone: (310)555-1234. Description: TheNMD_R1isapopularAdidascasualshoeknownforitscomfortablefit andmoderndesign.Itfeaturesastretchmeshupper,Boostmidsolefor cushioning,andEVAplugsforstability.']

# %%
shoe_chunks[2]
# Out:
# ["Adidas Superstar XLG Style:Classic Releasedate:January1,1969 Stylecode:21222 Originalretailprice:$85USD StoreLocation:MichiganAvenue,Chicago,IL60601.Phone:(312) 555-1234. Description: Theyfeaturearedandgreenleatherupperwithblackstripesanda rubbershelltoe.Thesoleiswhite. TheSuperstarisoneofAdidas'smosticonicsneakers,knownforitsclean designandclassiclook.Itfeaturesafull-grainleatherupper,rubbershell toe,andherringbone-patternrubbercupsole."]

# %%
shoe_chunks[3]
# Out:
# ['Adidas Yeezy Boost 350 V2 Style:Lifestyle Releasedate:November23,2016 Stylecode:BY1604 Originalretailprice:$220USD StoreLocation:MelroseAvenue,LosAngeles,CA90069.Phone:(323) 555-1234. Description: TheyfeatureablackandwhitePrimeknitupperwithaBoostmidsole.The soleisblack. TheYeezyBoost350V2isapopularAdidaslifestyleshoedesignedby KanyeWest.ItfeaturesaPrimeknitupper,Boostmidsoleforcushioning, andarubberoutsolefortraction.']

# %%
len(shoe_chunks)
# Out:
# 20

# %%
# Method to generate embeddings only
def generate_embeddings(textt):
    embedding_model = GoogleGenerativeAIEmbeddings(model="models/embedding-001" , google_api_key="AIzaSyBgAFP91jmm8Z9mJ4bNmARwInxZdObRa-M" )
    text_embeddings = [embedding_model.embed_query(text) for text in textt]
    return text_embeddings

# Text embedding
count = 1
text_embeddings=[]
for shoe in shoe_chunks:
    print("Embeddings for shoe: ", count)
    embeddings = generate_embeddings(shoe)
    text_embeddings.append(embeddings)
    print(embeddings)
    count = count + 1
# Out:
# Embeddings for shoe:  1
# ...

# %%
text_embeddings[0]
# Out:
# [[-0.012434493750333786,
#   -0.049517709761857986,
#   -0.018119830638170242,
#   -0.021377233788371086,
#   0.008671623654663563,
#   0.005358180962502956,
#   0.016150927171111107,
#   0.008502708747982979,
#   0.04617417976260185,
#   -0.007112628780305386,
#   0.03455245867371559,
#   0.048751410096883774,
#   -0.005132943391799927,
#   0.011671540327370167,
#   0.004879149608314037,
#   -0.056371789425611496,
#   0.020305326208472252,
#   0.013408275321125984,
#   0.0322033166885376,
#   -0.004602695815265179,
#   -0.05812279134988785,
#   -0.028421619907021523,
#   0.07702115178108215,
#   -0.002676478587090969,
#   -0.00458667054772377,
#   -0.07065349072217941,
#   0.017489692196249962,
#   -0.029677828773856163,
#   -0.030198777094483376,
#   -0.029816869646310806,
#   -0.04159275069832802,
#   0.04055437073111534,
#   -0.03515520319342613,
#   -0.01670609787106514,
#   0.023477748036384583,
#   -0.045084789395332336,
#   -0.007950491271913052,
#   0.06706363707780838,
# ...

# %%
# Extract embeddings list from the list of lists
embeddings_list=[]
for emb in text_embeddings:
  embeddings_list.append(emb[0])
  print(emb[0])
# Extract document list from the list of lists
doc_list=[]
for shoe in shoe_chunks:
  doc_list.append(shoe[0])
# Out:
# [-0.012434493750333786, -0.049517709761857986, -0.018119830638170242, -0.021377233788371086, 0.008671623654663563, 0.005358180962502956, 0.016150927171111107, 0.008502708747982979, 0.04617417976260185, -0.007112628780305386, 0.03455245867371559, 0.048751410096883774, -0.005132943391799927, 0.011671540327370167, 0.004879149608314037, -0.056371789425611496, 0.020305326208472252, 0.013408275321125984, 0.0322033166885376, -0.004602695815265179, -0.05812279134988785, -0.028421619907021523, 0.07702115178108215, -0.002676478587090969, -0.00458667054772377, -0.07065349072217941, 0.017489692196249962, -0.029677828773856163, -0.030198777094483376, -0.029816869646310806, -0.04159275069832802, 0.04055437073111534, -0.03515520319342613, -0.01670609787106514, 0.023477748036384583, -0.045084789395332336, -0.007950491271913052, 0.06706363707780838, -0.026925265789031982, 0.051365263760089874, -0.027703048661351204, -0.024160295724868774, -0.022696789354085922, -0.02458517998456955, 0.019037296995520
# ...

# %%
# Create the chromadb client
client = chromadb.Client()
# Create db collection
collection_name = "products_embeddings_collection"
client.get_or_create_collection(
    name=collection_name,
    metadata={"hnsw:space": "cosine"}
)
# Create a list of IDs
ids = list(map(str, range(1, 21)))
# Store the documents and text embeddings
product_embeddings_collection = client.get_collection(name=collection_name)
product_embeddings_collection.add(
    documents=doc_list,
    embeddings=embeddings_list,
    ids=ids
)

# %%
# Input side

input_text= "Suggest the best shoes for gradeschool kids"
text_chunks = get_text_chunks_langchain(input_text)
input_embeddings = generate_embeddings([chunk for chunk in text_chunks])

# %%
input_embeddings
# Out:
# [[0.0008556485408917069,
#   -0.06067853420972824,
#   -0.018672022968530655,
#   -0.026901056990027428,
#   0.05104902759194374,
#   0.04098187014460564,
#   0.004348014015704393,
#   -0.013324487954378128,
#   -0.022044114768505096,
#   0.054660189896821976,
#   0.09935762733221054,
#   0.028080612421035767,
#   0.035817477852106094,
#   -0.01071163546293974,
#   0.0037927767261862755,
#   -0.04475449025630951,
#   0.001709716860204935,
#   -0.04785822331905365,
#   0.05249102786183357,
#   -0.014103787019848824,
#   0.03623775765299797,
#   0.001818131422623992,
#   0.014731138944625854,
#   0.013627602718770504,
#   0.01976950466632843,
#   -0.04833104461431503,
#   -0.01543953362852335,
#   -0.054925717413425446,
#   0.005528231617063284,
#   0.05955691635608673,
#   -0.08219374716281891,
#   0.04947303608059883,
#   -0.06858783215284348,
#   -0.07382981479167938,
#   0.003602253971621394,
#   -0.019589824602007866,
#   -0.02036339044570923,
#   -0.021981438621878624,
# ...

# %%
# Text retrieval through RAG
def generation(retriever, input_text):
  llm_text = ChatGoogleGenerativeAI(model="gemini-1.5-pro-latest" , api_key="AIzaSyBgAFP91jmm8Z9mJ4bNmARwInxZdObRa-M")
  template = """
  ```
  {context}
  ```

  {information}


  First greet!
  Display similar shoes from the provided "{context}" only strictly meeting the "{information}" criteria; say a message that you found and provide the following information in a bullet format about the shoe using the {context}: Shoes name, Brand name, Style, Style code, Original retail price, Store Location and description.
  If you don’t find relevant shoes from the provided "{context}", simply say that We have no such shoes. Apologies.
  """
  prompt = ChatPromptTemplate.from_template(template)

  rag_chain = (
      {"context": RunnablePassthrough(), "information": RunnablePassthrough()}
      | prompt
      | llm_text
      | StrOutputParser()
  )
  # Passing text as input data

  result = rag_chain.invoke({"context": retriever, "information": input_text})
  return result

# %%
results = product_embeddings_collection.query(
  input_embeddings,
  n_results=2
)
result =generation(results, input_text)

# %%
print(result)
# Out:
# Hi there! I found a great shoe for grade school kids:
#
# **Reebok XANUEL AALeather Grade School**
#
# * **Brand name:** Reebok
# * **Style:** Training
# * **Style code:** FW8470
# * **Original retail price:** $130USD
# * **Store Location:** The Shops at Merrick Park, Coral Gables, FL 33134. Phone: (305) 555-1234.
# * **Description:** They feature a black, green, pink and white textile upper with a Flexweave woven fabric and a rubber outsole for grade school kids. The sole is white. The Reebok XANUEL AALeather is a popular Reebok training shoe known for its durable design and comfortable fit. It features a Flexweave woven fabric upper, a cushioned midsole, and a rubber outsole for traction.

# %%
# Input side

input_text1= "Suggest the best shoes to play tennis"
text_chunks1 = get_text_chunks_langchain(input_text1)
input_embeddings = generate_embeddings([chunk for chunk in text_chunks1])

# %%
input_embeddings
# Out:
# [[0.015882574021816254,
#   -0.0473935566842556,
#   0.018376590684056282,
#   -0.058211009949445724,
#   0.04193364456295967,
#   0.053126443177461624,
#   0.012512966059148312,
#   0.01282744761556387,
#   -0.00601588049903512,
#   0.06376468390226364,
#   0.0744001641869545,
#   0.0291904266923666,
#   0.03435486927628517,
#   -0.0045277210883796215,
#   0.005365367047488689,
#   -0.04409081116318703,
#   0.002296488033607602,
#   -0.05238296464085579,
#   0.01846166141331196,
#   0.01585913635790348,
#   0.018959729000926018,
#   -0.004701932892203331,
#   0.017968354746699333,
#   0.00325597426854074,
#   0.04697490110993385,
#   -0.05810904502868652,
#   -0.037689208984375,
#   -0.011683531105518341,
#   0.0032219800632447004,
#   0.08191481977701187,
#   -0.0956779345870018,
#   0.040645111352205276,
#   -0.07210460305213928,
#   -0.0538078173995018,
#   0.023094426840543747,
#   -0.009862866252660751,
#   -0.019370686262845993,
#   0.01712900958955288,
# ...

# %%
results1 = product_embeddings_collection.query(
  input_embeddings,
  n_results=2
)
result1 =generation(results1, input_text1)

# %%
print(results1)
# Out:
# {'ids': [['5', '6']], 'embeddings': None, 'documents': [['Adidas Stan Smith Lux Style:Tennis Releasedate:1971 Stylecode:M20324 Originalretailprice:$75USD StoreLocation:UnionSquare,SanFrancisco,CA94111.Phone:(415) 555-1234. Description: Theyfeatureawhiteleatherupperwithblueaccentsandarubber cupsole.Thesoleiswhite. TheStanSmithisaAdidastennisshoeknownforitsminimalistdesignand timelessstyle.Itfeaturesafull-grainleatherupper,perforated3-Stripes, andarubbercupsole.', 'Puma RS-X3 Style:Low-top Releasedate:March12,2020 Stylecode:372884-01 Originalretailprice:$110USD StoreLocation:TheDomain,Austin,TX78757.Phone:(512)555-1234. Description: Theyfeatureacolorfulmeshandtextileupperwithsyntheticoverlaysand anRSfoammidsole.Thesoleisrubber. TheRS-X3isapopularPumasneakerknownforitsbolddesignand comfortablefit.Itfeaturesameshandtextileupperwithsynthetic overlays,anRSfoammidsoleforcushioning,andarubberoutsolefor traction.']], 'uris': None, 'data': None, 'metadatas': [[None, None]], 'distances': [[0.29
# ...

# %%
print(result1)
# Out:
# Hi there!
#
# I found a great shoe for playing tennis!
#
# * **Shoes name:** Stan Smith Lux
# * **Brand name:** Adidas
# * **Style:** Tennis
# * **Style code:** M20324
# * **Original retail price:** $75USD
# * **Store Location:** Union Square, San Francisco, CA 94111. Phone: (415) 555-1234.
# * **Description:**  They feature a white leather upper with blue accents and a rubber cupsole. The sole is white. The Stan Smith is a Adidas tennis shoe known for its minimalist design and timeless style. It features a full-grain leather upper, perforated 3-Stripes, and a rubber cupsole.
