# %%
! pip install PyPDF2
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 5.6 MB/s eta 0:00:00
# ...

# %%
# !pip install langchain-google-genai
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.6/50.6 kB 2.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.4/40.4 kB 2.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 407.7/407.7 kB 17.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.9/296.9 kB 18.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.0/78.0 kB 4.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.5/144.5 kB 9.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 3.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 3.9 MB/s eta 0:00:00
# ...

# %%
# !pip install langchain
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 17.8 MB/s eta 0:00:00
# ...

# %%
# !pip install langchain-community
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 31.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.5/49.5 kB 3.1 MB/s eta 0:00:00
# ...

# %%
# !pip install chromadb
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 4.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 607.0/607.0 kB 24.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 64.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 273.8/273.8 kB 19.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.6/94.6 kB 7.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 63.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.2/93.2 kB 6.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.2/13.2 MB 64.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.5/52.5 kB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.7/149.7 kB 11.6 MB/s eta 0:00:00
# ...

# %%
# !pip install pdfplumber
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.0/42.0 kB 2.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.5/48.5 kB 2.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.2/59.2 kB 4.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 57.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 54.7 MB/s eta 0:00:00
# ...

# %%
# !pip install mediapipe
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.9/35.9 MB 44.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.6/294.6 kB 17.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-metadata 1.16.1 requires protobuf<4.21,>=3.20.3; python_version < "3.11", but you have protobuf 4.25.5 which is incompatible.
# ...

# %%
# !pip install protobuf==3.20.3
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 16.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.25.5
#     Uninstalling protobuf-4.25.5:
#       Successfully uninstalled protobuf-4.25.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# mediapipe 0.10.15 requires protobuf<5,>=4.25.3, but you have protobuf 3.20.3 which is incompatible.
# ...

# %%
# Standard library imports
import os
import io
import getpass
import json

# Third-party library imports
import PyPDF2
import requests
import numpy as np
import cv2
import math
import pdfplumber
import matplotlib.pyplot as plt
from PIL import Image
import ipywidgets as widgets
from IPython.display import display, Markdown

# Google generative AI imports
import google.generativeai as genai

# LangChain imports
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_google_genai import GoogleGenerativeAIEmbeddings
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.schema.document import Document
from langchain_community.document_loaders import TextLoader
from langchain_core.runnables import RunnableLambda, RunnablePassthrough

# Chromadb imports
import chromadb
from chromadb import Documents, EmbeddingFunction, Embeddings

# Mediapipe imports
import mediapipe as mp
from mediapipe.tasks import python
from mediapipe.tasks.python import vision

# %%
GOOGLE_API_KEY ="Add your gemini key here"
genai.configure(api_key=GOOGLE_API_KEY)

# %%
# Method to generate chunks
def get_text_chunks_langchain(text):
    text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=1)
    chunks = text_splitter.split_text(text)
    docs = [x for x in chunks]
    return docs

# Method to process the PDF
def process_pdf(file_path):
    # PDF processing
    with open(file_path, 'rb') as file:
        pdf_reader = PyPDF2.PdfReader(file)
        pdf_pages = pdf_reader.pages

        # Create chunks for each shoe detail page
        shoe_details = []
        for page_num, page in enumerate(pdf_pages, start=1):

            page_text = page.extract_text()
            # Split the text into lines and remove any empty lines
            lines = [line.strip() for line in page_text.splitlines() if line.strip()]

            # Join lines into continuous text
            consolidated_text = ' '.join(lines)
            shoe_details.append(consolidated_text)

            # PDF reading is done

        # Generate chunks for each shoe detail
        shoe_chunks = []
        for shoe_detail in shoe_details:
              chunks = get_text_chunks_langchain(shoe_detail)
              shoe_chunks.append(chunks)

        return shoe_chunks

# %%
# Method to extract images from the PDF

def extract_images_from_pdf(pdf_path):
    images = []
    print("Extracted images from the PDF")
    with pdfplumber.open(pdf_path) as pdf:
        for page in pdf.pages:
            for img in page.images:
                try:
                    # Extract image coordinates
                    x0, top, x1, bottom = img['x0'], img['top'], img['x1'], img['bottom']
                    # Crop image from page
                    cropped_image = page.within_bbox((x0, top, x1, bottom)).to_image()
                    # Convert cropped image to bytes
                    image_stream = io.BytesIO()
                    cropped_image.save(image_stream, format='PNG')
                    pil_image = Image.open(image_stream).convert('RGB')  # Ensure RGB mode
                    display(pil_image)
                    images.append(np.array(pil_image))
                except Exception as e:
                    print(f"Error processing image: {e}")

    return images

# %%
shoe_chunks_latest = process_pdf("ShoesStore.pdf")

# %%
shoe_chunks_latest[0]
# Out:
# ['Adidas Ultraboost 22sneakers Style:Running Releasedate:February4,2021 Stylecode:FY0377 Originalretailprice:$180USD StoreLocation:5thAvenue&Broadway,NewYork,NY10011.Phone:(212) 555-1234. Description: TheyfeatureablackupperwithablackAdidasStripeslogoontheside andaBoostmidsoleforcushioning.Thesoleisblack. TheUltraboost22isapopularAdidasrunningshoethatcombinescomfort andperformance.ItfeaturesaPrimeknitupper,aBoostmidsolefor responsivecushioning,andaContinentalrubberoutsoleforsuperior traction.']

# %%
shoe_chunks_latest[1]
# Out:
# ['Adidas NMD_R1 sneakers Style:Casual Releasedate:December12,2015 Stylecode:S79168 Originalretailprice:$130USD StoreLocation:3rdStreetPromenade,SantaMonica,CA90401.Phone: (310)555-1234. Description: TheNMD_R1isapopularAdidascasualshoeknownforitscomfortablefit andmoderndesign.Itfeaturesastretchmeshupper,Boostmidsolefor cushioning,andEVAplugsforstability.']

# %%
shoe_chunks_latest[2]
# Out:
# ["Adidas Superstar XLG Style:Classic Releasedate:January1,1969 Stylecode:21222 Originalretailprice:$85USD StoreLocation:MichiganAvenue,Chicago,IL60601.Phone:(312) 555-1234. Description: Theyfeaturearedandgreenleatherupperwithblackstripesanda rubbershelltoe.Thesoleiswhite. TheSuperstarisoneofAdidas'smosticonicsneakers,knownforitsclean designandclassiclook.Itfeaturesafull-grainleatherupper,rubbershell toe,andherringbone-patternrubbercupsole."]

# %%
shoe_chunks_latest[3]
# Out:
# ['Adidas Yeezy Boost 350 V2 Style:Lifestyle Releasedate:November23,2016 Stylecode:BY1604 Originalretailprice:$220USD StoreLocation:MelroseAvenue,LosAngeles,CA90069.Phone:(323) 555-1234. Description: TheyfeatureablackandwhitePrimeknitupperwithaBoostmidsole.The soleisblack. TheYeezyBoost350V2isapopularAdidaslifestyleshoedesignedby KanyeWest.ItfeaturesaPrimeknitupper,Boostmidsoleforcushioning, andarubberoutsolefortraction.']

# %%
len(shoe_chunks_latest)
# Out:
# 20

# %%
images = extract_images_from_pdf("ShoesStore.pdf")
# Out:
# Extracted images from the PDF
# <PIL.Image.Image image mode=RGB size=468x186>
# <PIL.Image.Image image mode=RGB size=468x197>
# <PIL.Image.Image image mode=RGB size=468x230>
# <PIL.Image.Image image mode=RGB size=468x192>
# <PIL.Image.Image image mode=RGB size=468x206>
# <PIL.Image.Image image mode=RGB size=468x210>
# <PIL.Image.Image image mode=RGB size=468x210>
# <PIL.Image.Image image mode=RGB size=468x215>
# <PIL.Image.Image image mode=RGB size=468x215>
# <PIL.Image.Image image mode=RGB size=468x215>
# <PIL.Image.Image image mode=RGB size=223x196>
# <PIL.Image.Image image mode=RGB size=258x224>
# <PIL.Image.Image image mode=RGB size=468x194>
# <PIL.Image.Image image mode=RGB size=223x165>
# <PIL.Image.Image image mode=RGB size=223x165>
# <PIL.Image.Image image mode=RGB size=259x160>
# <PIL.Image.Image image mode=RGB size=223x156>
# <PIL.Image.Image image mode=RGB size=223x138>
# <PIL.Image.Image image mode=RGB size=223x138>
# <PIL.Image.Image image mode=RGB size=223x138>

# %%
images[0]
# Out:
# array([[[234, 234, 240],
#         [234, 234, 240],
#         [234, 234, 240],
#         ...,
#         [234, 234, 240],
#         [234, 234, 240],
#         [234, 234, 240]],
#
#        [[234, 234, 240],
#         [234, 234, 240],
#         [234, 234, 240],
#         ...,
#         [234, 234, 240],
#         [234, 234, 240],
#         [234, 234, 240]],
#
#        [[234, 234, 240],
#         [234, 234, 240],
#         [234, 234, 240],
#         ...,
#         [234, 234, 240],
#         [234, 234, 240],
#         [234, 234, 240]],
#
#        ...,
#
#        [[234, 234, 240],
#         [234, 234, 240],
#         [234, 234, 240],
#         ...,
#         [234, 234, 240],
#         [234, 234, 240],
#         [234, 234, 240]],
#
#        [[234, 234, 240],
#         [234, 234, 240],
#         [234, 234, 240],
#         ...,
#         [234, 234, 240],
#         [234, 234, 240],
#         [234, 234, 240]],
#
#        [[234, 234, 240],
#         [234, 234, 240],
#         [234, 234, 240],
# ...

# %%
images[4]
# Out:
# array([[[234, 234, 240],
#         [234, 234, 240],
#         [234, 234, 240],
#         ...,
#         [233, 233, 231],
#         [233, 233, 231],
#         [243, 242, 242]],
#
#        [[234, 234, 240],
#         [234, 234, 240],
#         [234, 234, 240],
#         ...,
#         [233, 233, 231],
#         [233, 233, 231],
#         [243, 242, 242]],
#
#        [[234, 234, 240],
#         [234, 234, 240],
#         [234, 234, 240],
#         ...,
#         [233, 233, 231],
#         [233, 233, 231],
#         [243, 242, 242]],
#
#        ...,
#
#        [[234, 234, 240],
#         [234, 234, 240],
#         [234, 234, 240],
#         ...,
#         [234, 234, 240],
#         [234, 234, 240],
#         [234, 234, 240]],
#
#        [[234, 234, 240],
#         [234, 234, 240],
#         [234, 234, 240],
#         ...,
#         [234, 234, 240],
#         [234, 234, 240],
#         [234, 234, 240]],
#
#        [[234, 234, 240],
#         [234, 234, 240],
#         [234, 234, 240],
# ...

# %%
len(images)
# Out:
# 20

# %%
# Download the image embedding model

# !wget -O embedder.tflite -q https://storage.googleapis.com/mediapipe-models/image_embedder/mobilenet_v3_small/float32/1/mobilenet_v3_small.tflite

# Method to create mp images
def create_mp_image_from_np_array(image_np):
    return mp.Image(image_format=mp.ImageFormat.SRGB, data=image_np)
# Method to generate image embeddings
def embed_images_with_mediapipe(images):
    base_options = python.BaseOptions(model_asset_path='embedder.tflite')
    l2_normalize = True
    quantize = True
    options = vision.ImageEmbedderOptions(
        base_options=base_options, l2_normalize=l2_normalize, quantize=quantize)

    with vision.ImageEmbedder.create_from_options(options) as embedder:
        mp_images = [create_mp_image_from_np_array(image_np) for image_np in images]

        # Embed each image
        embedding_results = []
        for image in mp_images:
            embedding_result = embedder.embed(image)
            embeddings = np.array(embedding_result.embeddings[0].embedding, dtype=np.uint8)
            embedding_results.append(embeddings)


        return embedding_results  # Return the list of embedding arrays

# %%
image_embeddings = embed_images_with_mediapipe(images)

# %%
len(image_embeddings)
# Out:
# 20

# %%
image_embeddings[0]
# Out:
# array([254,   0, 255, ...,  14, 254, 255], dtype=uint8)

# %%
# Convert image embeddings to lists
image_embeddings = [embedding.tolist() if isinstance(embedding, np.ndarray) else embedding for embedding in image_embeddings]
# Extract document list from the list of lists
doc_list = [shoe[0] for shoe in shoe_chunks_latest]

# %%
client = chromadb.Client()
# Create db collection
collection_name = "products_embeddings_collection"
client.create_collection(
    name=collection_name,
    metadata={"hnsw:space": "cosine"}
)
# Create a list of IDs
ids = list(map(str, range(1, 21)))
# Store the text documents and text embeddings
product_embeddings_collection  = client.get_collection(name=collection_name)
product_embeddings_collection.add(
    documents=doc_list,
    embeddings=image_embeddings,
    ids=ids
)

# %%
# Input side
image_path = 'Puma.png'
# Display the input image
image = Image.open(image_path)
plt.imshow(image)
# Turn off axis numbers and ticks
plt.axis('off')
plt.show()
# Generate embeddings of the input image
query_image = cv2.imread(image_path)
query_image_embedding = embed_images_with_mediapipe([query_image])[0]
# Convert image embeddings to lists
query_image_embedding = [embedding.tolist() for embedding in query_image_embedding]

# %%
print(query_image_embedding)
# Out:
# [254, 3, 254, 5, 254, 1, 1, 254, 254, 0, 254, 3, 2, 0, 254, 0, 0, 255, 254, 254, 254, 0, 254, 254, 254, 254, 0, 0, 2, 0, 5, 4, 254, 6, 254, 2, 0, 254, 0, 0, 0, 9, 1, 0, 255, 6, 254, 255, 5, 0, 0, 2, 254, 2, 255, 254, 254, 0, 0, 255, 254, 254, 254, 254, 7, 254, 255, 3, 254, 4, 254, 2, 3, 7, 2, 0, 0, 255, 1, 0, 11, 254, 1, 254, 255, 1, 254, 2, 254, 1, 254, 3, 0, 255, 254, 254, 1, 4, 0, 1, 1, 4, 255, 255, 2, 254, 12, 254, 6, 9, 254, 1, 3, 254, 254, 2, 1, 254, 255, 255, 254, 2, 6, 0, 0, 255, 254, 254, 255, 254, 254, 255, 254, 254, 0, 7, 3, 11, 255, 254, 254, 254, 254, 0, 254, 254, 254, 254, 254, 255, 0, 254, 0, 0, 254, 255, 4, 254, 3, 254, 254, 0, 6, 254, 0, 254, 10, 1, 254, 255, 254, 2, 2, 254, 254, 254, 255, 11, 254, 254, 0, 254, 255, 255, 1, 8, 255, 254, 254, 0, 0, 0, 254, 4, 0, 6, 254, 255, 254, 5, 254, 8, 254, 6, 0, 254, 254, 1, 1, 2, 1, 255, 2, 6, 254, 255, 255, 255, 254, 254, 0, 255, 2, 255, 2, 254, 3, 0, 254, 4, 254, 255, 0, 254, 9, 0, 254, 10, 16, 4, 1, 255, 3, 3, 254, 0, 1, 255
# ...

# %%
# Retrieve relevant documents
results = product_embeddings_collection.query(
  query_image_embedding,
  n_results=5
)
print(results)
# Out:
# {'ids': [['6', '16', '8', '20', '2']], 'embeddings': None, 'documents': [['Puma RS-X3 Style:Low-top Releasedate:March12,2020 Stylecode:372884-01 Originalretailprice:$110USD StoreLocation:TheDomain,Austin,TX78757.Phone:(512)555-1234. Description: Theyfeatureacolorfulmeshandtextileupperwithsyntheticoverlaysand anRSfoammidsole.Thesoleisrubber. TheRS-X3isapopularPumasneakerknownforitsbolddesignand comfortablefit.Itfeaturesameshandtextileupperwithsynthetic overlays,anRSfoammidsoleforcushioning,andarubberoutsolefor traction.', "ReebokLeather Style:Retro Releasedate:April1,1983 Stylecode:49799 Originalretailprice:$75USD StoreLocation:TimesSquare,NewYork,NY10036.Phone:(212)555-5678. Description: TheyfeatureawhiteandblueleatherupperwithaReeboklogoonthe sideandanEVAmidsoleforcushioning.Thesoleisgumrubber. TheLeatherisoneofReebok'smosticonicsilhouettes,knownforitsclean designandtimelessstyle.Itfeaturesafull-grainleatherupper,anEVA midsoleforlightweightcushioning,andahigh-abrasionrubberoutsolefo
# ...

# %%
# Image retrieval through RAG
def generation(retriever, query_image):
  llm_text = ChatGoogleGenerativeAI(model="gemini-1.5-pro-latest" , api_key="AIzaSyBgAFP91jmm8Z9mJ4bNmARwInxZdObRa-M")
  template = """
  ```
  {context}
  ```

  {information}


  First greet!
  Pick the image from the given {context} that is the nearest to the {information} and Provide following information in a bullet format about the shoe using the {information}: Shoes name, Brand name, Style, Style code, Original retail price, Store Location and description.
  If the {information} is not available in the {context}, just return "Not available in the store, Apologies"
  """
  prompt = ChatPromptTemplate.from_template(template)

  rag_chain = (
      {"context": RunnablePassthrough(), "information": RunnablePassthrough()}
      | prompt
      | llm_text
      | StrOutputParser()
  )
  # Passing image as input data

  result = rag_chain.invoke({"context": retriever, "information": query_image})
  return result

# %%
result = generation(results ,"Puma.png")
print(result)
# Out:
# Hello!
#
# The image is of **Puma RS-X3** shoes. And here are the details:
#
# * **Shoes name:** Puma RS-X3
# * **Brand name:** Puma
# * **Style:** Low-top
# * **Style code:** 372884-01
# * **Original retail price:** $110 USD
# * **Store Location:** The Domain, Austin, TX 78757. Phone: (512) 555-1234.
# * **Description:** They feature a colorful mesh and textile upper with synthetic overlays and an RS foam midsole. The sole is rubber. The RS-X3 is a popular Puma sneaker known for its bold design and comfortable fit. It features a mesh and textile upper with synthetic overlays, an RS foam midsole for cushioning, and a rubber outsole for traction.

# %%
# Input side
image_path = 'Adidas.png'
# Display the input image
image = Image.open(image_path)
plt.imshow(image)
# Turn off axis numbers and ticks
plt.axis('off')
plt.show()
# Generate embeddings of the input image
query_image = cv2.imread(image_path)
query_image_embedding = embed_images_with_mediapipe([query_image])[0]
# Convert image embeddings to lists
query_image_embedding = [embedding.tolist() for embedding in query_image_embedding]

# %%
print(query_image_embedding)
# Out:
# [254, 2, 0, 5, 5, 3, 255, 2, 255, 0, 1, 3, 16, 254, 254, 0, 0, 9, 254, 255, 254, 255, 3, 0, 254, 254, 254, 0, 0, 254, 254, 254, 0, 0, 254, 254, 2, 255, 0, 3, 0, 1, 255, 4, 254, 17, 255, 254, 254, 255, 255, 6, 4, 0, 255, 254, 254, 0, 4, 254, 255, 254, 1, 255, 7, 0, 254, 9, 255, 254, 255, 254, 2, 255, 5, 7, 0, 0, 255, 254, 13, 1, 255, 3, 0, 5, 254, 254, 254, 255, 254, 255, 255, 0, 0, 254, 254, 255, 0, 1, 255, 5, 254, 0, 0, 5, 0, 255, 2, 255, 255, 0, 255, 3, 254, 254, 3, 0, 0, 255, 254, 4, 9, 255, 1, 2, 255, 0, 254, 254, 0, 254, 0, 255, 0, 1, 3, 2, 254, 255, 255, 6, 254, 254, 254, 0, 254, 0, 254, 254, 255, 8, 0, 0, 254, 254, 254, 254, 255, 0, 255, 255, 254, 0, 255, 0, 7, 1, 254, 255, 0, 0, 2, 11, 0, 255, 0, 255, 255, 0, 0, 254, 255, 254, 254, 254, 0, 3, 254, 0, 255, 0, 254, 255, 254, 1, 0, 254, 0, 254, 0, 3, 255, 254, 4, 1, 255, 3, 4, 3, 9, 0, 1, 3, 0, 0, 2, 4, 255, 2, 254, 3, 4, 255, 255, 255, 254, 0, 254, 255, 0, 254, 0, 0, 13, 255, 0, 21, 254, 8, 255, 254, 255, 255, 255, 255, 0, 0, 1
# ...

# %%
# Retrieve relevant documents
results = product_embeddings_collection.query(
  query_image_embedding,
  n_results=5
)
print(results)
# Out:
# {'ids': [['4', '8', '19', '1', '2']], 'embeddings': None, 'documents': [['Adidas Yeezy Boost 350 V2 Style:Lifestyle Releasedate:November23,2016 Stylecode:BY1604 Originalretailprice:$220USD StoreLocation:MelroseAvenue,LosAngeles,CA90069.Phone:(323) 555-1234. Description: TheyfeatureablackandwhitePrimeknitupperwithaBoostmidsole.The soleisblack. TheYeezyBoost350V2isapopularAdidaslifestyleshoedesignedby KanyeWest.ItfeaturesaPrimeknitupper,Boostmidsoleforcushioning, andarubberoutsolefortraction.', 'Puma Future Rider Splash Toddlers’ Style:Casual Releasedate:January23,2020 Stylecode:371149-01 Originalretailprice:$80USD StoreLocation:DupontCircle,WashingtonD.C.20007.Phone:(202) 555-1234. Description: Theyfeatureawhite,blackandpinktextileupperwithsuedeoverlaysand aRiderFoammidsole.Thesoleisrubber. TheFutureRiderisapopularPumacasualshoeknownforitsretrodesign andcomfortablefit.Itfeaturesatextileupperwithsuedeoverlays,aRider Foammidsoleforcushioning,andarubberoutsolefortraction.', "Reebok ZigKi
# ...

# %%
output = generation(results ,"Adidas.png")
print(output)
# Out:
# Hello!
#
# The Adidas.png shoe is the **Adidas Yeezy Boost 350 V2**.
#
# Here is some information about the shoe:
#
# * **Shoes name:** Adidas Yeezy Boost 350 V2
# * **Brand name:** Adidas
# * **Style:** Lifestyle
# * **Style code:** BY1604
# * **Original retail price:** $220 USD
# * **Store Location:** Melrose Avenue, Los Angeles, CA 90069. Phone: (323) 555-1234
# * **Description:** They feature a black and white Primeknit upper with a Boost midsole. The sole is black. The Yeezy Boost 350 V2 is a popular Adidas lifestyle shoe designed by Kanye West. It features a Primeknit upper, Boost midsole for cushioning, and a rubber outsole for traction.
